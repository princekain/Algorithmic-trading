# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright by Pierian Data Inc.</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Pandas Project Exercise -
#
# # The Data
#
# The dataset contains a list of all stocks included in the SP500 and associated key financials. <br />
#
# Note that there are multiple viable solutions for most of the tasks!
#
#
# Acknowledgements
# ----------------------------
# The dataset was originally provided on https://datahub.io/core/s-and-p-500-companies-financials and is licensed under Open Data Commons Public Domain Dedication and License. (https://opendatacommons.org/licenses/pddl/1-0/)

# %% [markdown]
# **Task: Import the necessary libraries**

# %%
# CODE HERE
import numpy as np
import pandas as pd

# %% [markdown]
# **Task: Read the two datasets provided in the current directory (also available in the DATA folder. (The file names are: constituents.csv and constituents-financials.csv)**

# %%
# CODE HERE
df=pd.read_csv("constituents.csv")
df1=pd.read_csv("constituents-financials.csv")
df1
# Out:
#     Symbol   Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# 0      MMM  222.89           24.31        2.332862            7.92
# 1      AOS   60.24           27.76        1.147959            1.70
# 2      ABT   56.27           22.51        1.908982            0.26
# 3     ABBV  108.48           19.41        2.499560            3.29
# 4      ACN  150.51           25.47        1.714470            5.44
# ..     ...     ...             ...             ...             ...
# 500    XYL   70.24           30.94        1.170079            1.83
# 501    YUM   76.30           27.25        1.797080            4.07
# 502    ZBH  115.53           14.32        0.794834            9.01
# 503   ZION   50.71           17.73        1.480933            2.60
# 504    ZTS   71.51           32.80        0.682372            1.65
#
#      52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# 0         259.77       175.490  138721055226  9.048000e+09     4.390271
# 1          68.39        48.925   10783419933  6.010000e+08     3.575483
# 2          64.60        42.280  102121042306  5.744000e+09     3.740480
# 3         125.86        60.050  181386347059  1.031000e+10     6.291571
# 4         162.60       114.820   98765855553  5.643228e+09     2.604117
# ..           ...           ...           ...           ...          ...
# 500        76.81        46.860   12915021000  7.220000e+08     2.726209
# 501        86.93        62.850   27003303098  2.289000e+09     6.313636
# 502       133.49       108.170   24454698119  2.007400e+09     3.164895
# 503        55.61        38.430   10670678640  0.000000e+00     3.794579
# 504        80.13        52.000   35991109776  1.734000e+09     9.280896
#
#      Price/Book                                        SEC Filings
# 0         11.34  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1          6.35  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2          3.19  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3         26.14  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4         10.62  http://www.sec.gov/cgi-bin/browse-edgar?action...
# ..          ...                                                ...
# 500        5.31  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 501      212.08  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 502        2.39  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 503        1.42  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 504       18.09  http://www.sec.gov/cgi-bin/browse-edgar?action...
#
# [505 rows x 12 columns]

# %% [markdown]
# **Task: List all columns of the two datasets. Additionally retrieve the datatype for each column**

# %%
# CODE HERE
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          505 non-null    object
#  1   Price           505 non-null    float64
#  2   Price/Earnings  503 non-null    float64
#  3   Dividend Yield  505 non-null    float64
#  4   Earnings/Share  505 non-null    float64
#  5   52 Week Low     505 non-null    float64
#  6   52 Week High    505 non-null    float64
#  7   Market Cap      505 non-null    int64
#  8   EBITDA          505 non-null    float64
#  9   Price/Sales     505 non-null    float64
#  10  Price/Book      497 non-null    float64
#  11  SEC Filings     505 non-null    object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 47.5+ KB

# %% [markdown]
# **Task: Print the first 5 rows of both datasets**

# %%
# CODE HERE
df.head()
df1.head()
# Out:
#   Symbol   Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0    MMM  222.89           24.31        2.332862            7.92       259.77
# 1    AOS   60.24           27.76        1.147959            1.70        68.39
# 2    ABT   56.27           22.51        1.908982            0.26        64.60
# 3   ABBV  108.48           19.41        2.499560            3.29       125.86
# 4    ACN  150.51           25.47        1.714470            5.44       162.60
#
#    52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book  \
# 0       175.490  138721055226  9.048000e+09     4.390271       11.34
# 1        48.925   10783419933  6.010000e+08     3.575483        6.35
# 2        42.280  102121042306  5.744000e+09     3.740480        3.19
# 3        60.050  181386347059  1.031000e+10     6.291571       26.14
# 4       114.820   98765855553  5.643228e+09     2.604117       10.62
#
#                                          SEC Filings
# 0  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %% [markdown]
# **Task: Drop the SEC Filings column**

# %%
# CODE HERE
df1=df1.drop('SEC Filings', axis=1)
df1
# Out:
#     Symbol   Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# 0      MMM  222.89           24.31        2.332862            7.92
# 1      AOS   60.24           27.76        1.147959            1.70
# 2      ABT   56.27           22.51        1.908982            0.26
# 3     ABBV  108.48           19.41        2.499560            3.29
# 4      ACN  150.51           25.47        1.714470            5.44
# ..     ...     ...             ...             ...             ...
# 500    XYL   70.24           30.94        1.170079            1.83
# 501    YUM   76.30           27.25        1.797080            4.07
# 502    ZBH  115.53           14.32        0.794834            9.01
# 503   ZION   50.71           17.73        1.480933            2.60
# 504    ZTS   71.51           32.80        0.682372            1.65
#
#      52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# 0         259.77       175.490  138721055226  9.048000e+09     4.390271
# 1          68.39        48.925   10783419933  6.010000e+08     3.575483
# 2          64.60        42.280  102121042306  5.744000e+09     3.740480
# 3         125.86        60.050  181386347059  1.031000e+10     6.291571
# 4         162.60       114.820   98765855553  5.643228e+09     2.604117
# ..           ...           ...           ...           ...          ...
# 500        76.81        46.860   12915021000  7.220000e+08     2.726209
# 501        86.93        62.850   27003303098  2.289000e+09     6.313636
# 502       133.49       108.170   24454698119  2.007400e+09     3.164895
# 503        55.61        38.430   10670678640  0.000000e+00     3.794579
# 504        80.13        52.000   35991109776  1.734000e+09     9.280896
#
#      Price/Book
# 0         11.34
# 1          6.35
# 2          3.19
# 3         26.14
# 4         10.62
# ..          ...
# 500        5.31
# 501      212.08
# 502        2.39
# 503        1.42
# 504       18.09
#
# [505 rows x 11 columns]

# %% [markdown]
# **Task: Set the Symbol column to the index in the financials dataset**

# %%
# CODE HERE
df1=df1.reset_index()
df1=df1.set_index('Symbol')
df1
# Out:
#         index   Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# Symbol
# MMM         0  222.89           24.31        2.332862            7.92
# AOS         1   60.24           27.76        1.147959            1.70
# ABT         2   56.27           22.51        1.908982            0.26
# ABBV        3  108.48           19.41        2.499560            3.29
# ACN         4  150.51           25.47        1.714470            5.44
# ...       ...     ...             ...             ...             ...
# XYL       500   70.24           30.94        1.170079            1.83
# YUM       501   76.30           27.25        1.797080            4.07
# ZBH       502  115.53           14.32        0.794834            9.01
# ZION      503   50.71           17.73        1.480933            2.60
# ZTS       504   71.51           32.80        0.682372            1.65
#
#         52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# Symbol
# MMM          259.77       175.490  138721055226  9.048000e+09     4.390271
# AOS           68.39        48.925   10783419933  6.010000e+08     3.575483
# ABT           64.60        42.280  102121042306  5.744000e+09     3.740480
# ABBV         125.86        60.050  181386347059  1.031000e+10     6.291571
# ACN          162.60       114.820   98765855553  5.643228e+09     2.604117
# ...             ...           ...           ...           ...          ...
# XYL           76.81        46.860   12915021000  7.220000e+08     2.726209
# YUM           86.93        62.850   27003303098  2.289000e+09     6.313636
# ZBH          133.49       108.170   24454698119  2.007400e+09     3.164895
# ZION          55.61        38.430   10670678640  0.000000e+00     3.794579
# ZTS           80.13        52.000   35991109776  1.734000e+09     9.280896
#
#         Price/Book
# Symbol
# MMM          11.34
# AOS           6.35
# ABT           3.19
# ABBV         26.14
# ACN          10.62
# ...            ...
# XYL           5.31
# YUM         212.08
# ZBH           2.39
# ZION          1.42
# ZTS          18.09
#
# [505 rows x 11 columns]

# %% [markdown]
# **Task: What are the 10 largest companies according to market cap?**

# %%
# CODE HERE
df1.nlargest(10,'Market Cap').filter('Symbol')
# Out:
# Empty DataFrame
# Columns: []
# Index: [AAPL, GOOGL, GOOG, MSFT, AMZN, FB, JPM, JNJ, XOM, BAC]

# %% [markdown]
# **Task: Return all information about the 10 largest companies according by market cap**

# %%
# CODE HERE
df1.nlargest(10,'Market Cap').describe().transpose()
# Out:
#                 count          mean           std           min           25%  \
# index            10.0  1.409000e+02  1.125694e+02  2.700000e+01  3.525000e+01
# Price            10.0  4.111520e+02  4.996584e+02  2.974000e+01  9.072750e+01
# Price/Earnings   10.0  5.089000e+01  8.654783e+01  1.543000e+01  1.697250e+01
# Dividend Yield   10.0  1.353472e+00  1.356073e+00  0.000000e+00  0.000000e+00
# Earnings/Share   10.0  7.838000e+00  8.053991e+00  3.900000e-01  2.152500e+00
# 52 Week Low      10.0  4.742023e+02  5.738627e+02  3.267000e+01  1.013907e+02
# 52 Week High     10.0  3.059675e+02  3.516702e+02  2.207000e+01  7.744625e+01
# Market Cap       10.0  5.558445e+11  1.941483e+11  3.214782e+11  3.614503e+11
# EBITDA           10.0  2.886340e+10  2.296415e+10  0.000000e+00  1.770650e+10
# Price/Sales      10.0  5.429057e+00  3.281669e+00  1.770194e+00  3.393277e+00
# Price/Book       10.0  6.531000e+00  6.741970e+00  1.240000e+00  2.555000e+00
#
#                          50%           75%           max
# index           1.255000e+02  2.425000e+02  3.110000e+02
# Price           1.407550e+02  7.940350e+02  1.350500e+03
# Price/Earnings  2.356500e+01  3.058500e+01  2.961600e+02
# Dividend Yield  1.557771e+00  1.957136e+00  4.003120e+00
# Earnings/Share  5.775000e+00  8.475000e+00  2.227000e+01
# 52 Week Low     1.642100e+02  9.389975e+02  1.498000e+03
# 52 Week High    1.221350e+02  6.355027e+02  8.243000e+02
# Market Cap      6.046482e+11  7.188963e+11  8.095080e+11
# EBITDA          2.816900e+10  3.784325e+10  7.938600e+10
# Price/Sales     4.279838e+00  6.794432e+00  1.324197e+01
# Price/Book      4.720000e+00  6.725000e+00  2.428000e+01

# %% [markdown]
# Note: The difference between GOOG and GOOGL is, that GOOG shares have no voting rights

# %% [markdown]
# **Task: Drop GOOG**

# %%
# CODE HERE
df1.drop(index="GOOG", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [16], in <cell line: 2>()
#       1 # CODE HERE
# ----> 2 df1.drop(index="GOOG", inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['GOOG'] not found in axis"

# %% [markdown]
# **Task: How many companies have a dividend yield > 4% ?**

# %%
# CODE HERE
count=0
bol=df1['Dividend Yield']>4
for i in bol:
    if(i==True):
        count=count+1
print(count)
# Out:
# 37

# %% [markdown]
# **Task: What is the mean Earnings per Share for all companies with a market cap > 1e+11**

# %%
# CODE HERE
bool_series=df1['Market Cap']>(1e+11)
df1=df1[bool_series]
df1["Earnings/Share"].mean()
# Out:
# 5.083461538461538

# %% [markdown]
# **Task: How many companies have a positive earnings per shares ratio?**

# %%
# CODE HERE
bool_series=df1['Earnings/Share']>0
df2=df1[bool_series]
df2
# Out:
#     Symbol   Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# 0      MMM  222.89           24.31        2.332862            7.92
# 1      AOS   60.24           27.76        1.147959            1.70
# 2      ABT   56.27           22.51        1.908982            0.26
# 3     ABBV  108.48           19.41        2.499560            3.29
# 4      ACN  150.51           25.47        1.714470            5.44
# ..     ...     ...             ...             ...             ...
# 500    XYL   70.24           30.94        1.170079            1.83
# 501    YUM   76.30           27.25        1.797080            4.07
# 502    ZBH  115.53           14.32        0.794834            9.01
# 503   ZION   50.71           17.73        1.480933            2.60
# 504    ZTS   71.51           32.80        0.682372            1.65
#
#      52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# 0         259.77       175.490  138721055226  9.048000e+09     4.390271
# 1          68.39        48.925   10783419933  6.010000e+08     3.575483
# 2          64.60        42.280  102121042306  5.744000e+09     3.740480
# 3         125.86        60.050  181386347059  1.031000e+10     6.291571
# 4         162.60       114.820   98765855553  5.643228e+09     2.604117
# ..           ...           ...           ...           ...          ...
# 500        76.81        46.860   12915021000  7.220000e+08     2.726209
# 501        86.93        62.850   27003303098  2.289000e+09     6.313636
# 502       133.49       108.170   24454698119  2.007400e+09     3.164895
# 503        55.61        38.430   10670678640  0.000000e+00     3.794579
# 504        80.13        52.000   35991109776  1.734000e+09     9.280896
#
#      Price/Book                                        SEC Filings  \
# 0         11.34  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1          6.35  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2          3.19  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3         26.14  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4         10.62  http://www.sec.gov/cgi-bin/browse-edgar?action...
# ..          ...                                                ...
# 500        5.31  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 501      212.08  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 502        2.39  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 503        1.42  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 504       18.09  http://www.sec.gov/cgi-bin/browse-edgar?action...
#
#      Market Cap in Billion
# 0               138.721055
# 1                10.783420
# 2               102.121042
# 3               181.386347
# 4                98.765856
# ..                     ...
# 500              12.915021
# 501              27.003303
# 502              24.454698
# 503              10.670679
# 504              35.991110
#
# [453 rows x 13 columns]

# %% [markdown]
# **Task: Which company pays the highest dividend yield? What was its 52 week high?**

# %%
# CODE HERE
df3=df1.sort_values('Dividend Yield',ascending=False)
sf=df3.iloc[0:1]
sf
# Out:
#         index  Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# Symbol
# CTL        99   16.2            8.35       12.661196            1.16
#
#         52 Week Low  52 Week High   Market Cap        EBITDA  Price/Sales  \
# Symbol
# CTL           27.61        13.161  18237196861  5.577000e+09     1.479598
#
#         Price/Book
# Symbol
# CTL           1.39

# %% [markdown]
# **Task: Return the company with the largest spread between 52 weeks high and low**

# %%
# CODE HERE

def spread(a,b):
    return a-b
arr=df1[['52 Week Low' ,'52 Week High']].apply(lambda df1:spread(df1['52 Week Low'],df1['52 Week High']),axis=1)
arr.max()
# Out:
# 685.5

# %% [markdown]
# **Task: Return all companies whith a price between \\$ 50 and \\$ 100**

# %%
# CODE HERE
l1=df1['Price']>50 
l2=df1['Price']<100
l3=l1&l2
l3
l4=df1[l3]
type(l4.filter(['EBITDA']))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Task: The market cap is really hard to read. Create a new column called "Market Cap in Billion" which shows the market cap in billions**

# %%
# CODE HERE
import pandas as pd
df1=pd.read_csv("constituents-financials.csv")
df1['Market Cap in Billion']=(10**(-9))*df1['Market Cap']
df1
# Out:
#     Symbol   Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# 0      MMM  222.89           24.31        2.332862            7.92
# 1      AOS   60.24           27.76        1.147959            1.70
# 2      ABT   56.27           22.51        1.908982            0.26
# 3     ABBV  108.48           19.41        2.499560            3.29
# 4      ACN  150.51           25.47        1.714470            5.44
# ..     ...     ...             ...             ...             ...
# 500    XYL   70.24           30.94        1.170079            1.83
# 501    YUM   76.30           27.25        1.797080            4.07
# 502    ZBH  115.53           14.32        0.794834            9.01
# 503   ZION   50.71           17.73        1.480933            2.60
# 504    ZTS   71.51           32.80        0.682372            1.65
#
#      52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# 0         259.77       175.490  138721055226  9.048000e+09     4.390271
# 1          68.39        48.925   10783419933  6.010000e+08     3.575483
# 2          64.60        42.280  102121042306  5.744000e+09     3.740480
# 3         125.86        60.050  181386347059  1.031000e+10     6.291571
# 4         162.60       114.820   98765855553  5.643228e+09     2.604117
# ..           ...           ...           ...           ...          ...
# 500        76.81        46.860   12915021000  7.220000e+08     2.726209
# 501        86.93        62.850   27003303098  2.289000e+09     6.313636
# 502       133.49       108.170   24454698119  2.007400e+09     3.164895
# 503        55.61        38.430   10670678640  0.000000e+00     3.794579
# 504        80.13        52.000   35991109776  1.734000e+09     9.280896
#
#      Price/Book                                        SEC Filings  \
# 0         11.34  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1          6.35  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2          3.19  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3         26.14  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4         10.62  http://www.sec.gov/cgi-bin/browse-edgar?action...
# ..          ...                                                ...
# 500        5.31  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 501      212.08  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 502        2.39  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 503        1.42  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 504       18.09  http://www.sec.gov/cgi-bin/browse-edgar?action...
#
#      Market Cap in Billion
# 0               138.721055
# 1                10.783420
# 2               102.121042
# 3               181.386347
# 4                98.765856
# ..                     ...
# 500              12.915021
# 501              27.003303
# 502              24.454698
# 503              10.670679
# 504              35.991110
#
# [505 rows x 13 columns]

# %% [markdown]
# **Task: Is there a correlation between the market cap and the Dividend Yield?**

# %%
# CODE HERE
df=pd.read_csv("constituents.csv")
lf1=pd.merge(df,df1,how='inner')
lf1
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# 1             27.76        1.147959            1.70        68.39
# 2             22.51        1.908982            0.26        64.60
# 3             19.41        2.499560            3.29       125.86
# 4             25.47        1.714470            5.44       162.60
# ..              ...             ...             ...          ...
# 500           30.94        1.170079            1.83        76.81
# 501           27.25        1.797080            4.07        86.93
# 502           14.32        0.794834            9.01       133.49
# 503           17.73        1.480933            2.60        55.61
# 504           32.80        0.682372            1.65        80.13
#
#      52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book  \
# 0         175.490  138721055226  9.048000e+09     4.390271       11.34
# 1          48.925   10783419933  6.010000e+08     3.575483        6.35
# 2          42.280  102121042306  5.744000e+09     3.740480        3.19
# 3          60.050  181386347059  1.031000e+10     6.291571       26.14
# 4         114.820   98765855553  5.643228e+09     2.604117       10.62
# ..            ...           ...           ...          ...         ...
# 500        46.860   12915021000  7.220000e+08     2.726209        5.31
# 501        62.850   27003303098  2.289000e+09     6.313636      212.08
# 502       108.170   24454698119  2.007400e+09     3.164895        2.39
# 503        38.430   10670678640  0.000000e+00     3.794579        1.42
# 504        52.000   35991109776  1.734000e+09     9.280896       18.09
#
#                                            SEC Filings  Market Cap in Billion
# 0    http://www.sec.gov/cgi-bin/browse-edgar?action...             138.721055
# 1    http://www.sec.gov/cgi-bin/browse-edgar?action...              10.783420
# 2    http://www.sec.gov/cgi-bin/browse-edgar?action...             102.121042
# 3    http://www.sec.gov/cgi-bin/browse-edgar?action...             181.386347
# 4    http://www.sec.gov/cgi-bin/browse-edgar?action...              98.765856
# ..                                                 ...                    ...
# 500  http://www.sec.gov/cgi-bin/browse-edgar?action...              12.915021
# 501  http://www.sec.gov/cgi-bin/browse-edgar?action...              27.003303
# 502  http://www.sec.gov/cgi-bin/browse-edgar?action...              24.454698
# 503  http://www.sec.gov/cgi-bin/browse-edgar?action...              10.670679
# 504  http://www.sec.gov/cgi-bin/browse-edgar?action...              35.991110
#
# [505 rows x 15 columns]

# %% [markdown]
# **Task: Merge the financials dataframe with the constituents dataframe**

# %%
# CODE HERE
lf1=pd.merge(df1,df,how='inner')
lf1
# Out:
#     Symbol   Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# 0      MMM  222.89           24.31        2.332862            7.92
# 1      AOS   60.24           27.76        1.147959            1.70
# 2      ABT   56.27           22.51        1.908982            0.26
# 3     ABBV  108.48           19.41        2.499560            3.29
# 4      ACN  150.51           25.47        1.714470            5.44
# ..     ...     ...             ...             ...             ...
# 500    XYL   70.24           30.94        1.170079            1.83
# 501    YUM   76.30           27.25        1.797080            4.07
# 502    ZBH  115.53           14.32        0.794834            9.01
# 503   ZION   50.71           17.73        1.480933            2.60
# 504    ZTS   71.51           32.80        0.682372            1.65
#
#      52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# 0         259.77       175.490  138721055226  9.048000e+09     4.390271
# 1          68.39        48.925   10783419933  6.010000e+08     3.575483
# 2          64.60        42.280  102121042306  5.744000e+09     3.740480
# 3         125.86        60.050  181386347059  1.031000e+10     6.291571
# 4         162.60       114.820   98765855553  5.643228e+09     2.604117
# ..           ...           ...           ...           ...          ...
# 500        76.81        46.860   12915021000  7.220000e+08     2.726209
# 501        86.93        62.850   27003303098  2.289000e+09     6.313636
# 502       133.49       108.170   24454698119  2.007400e+09     3.164895
# 503        55.61        38.430   10670678640  0.000000e+00     3.794579
# 504        80.13        52.000   35991109776  1.734000e+09     9.280896
#
#      Price/Book                                        SEC Filings  \
# 0         11.34  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1          6.35  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2          3.19  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3         26.14  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4         10.62  http://www.sec.gov/cgi-bin/browse-edgar?action...
# ..          ...                                                ...
# 500        5.31  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 501      212.08  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 502        2.39  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 503        1.42  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 504       18.09  http://www.sec.gov/cgi-bin/browse-edgar?action...
#
#      Market Cap in Billion                    Name                  Sector
# 0               138.721055              3M Company             Industrials
# 1                10.783420         A.O. Smith Corp             Industrials
# 2               102.121042     Abbott Laboratories             Health Care
# 3               181.386347             AbbVie Inc.             Health Care
# 4                98.765856           Accenture plc  Information Technology
# ..                     ...                     ...                     ...
# 500              12.915021              Xylem Inc.             Industrials
# 501              27.003303         Yum! Brands Inc  Consumer Discretionary
# 502              24.454698  Zimmer Biomet Holdings             Health Care
# 503              10.670679           Zions Bancorp              Financials
# 504              35.991110                  Zoetis             Health Care
#
# [505 rows x 15 columns]

# %% [markdown]
# **Task: Print all sectors. How often does each sector occur?**

# %%
# CODE HERE
lf1.filter(['Sector'])
lf1['Sector'].value_counts()
# Out:
# Consumer Discretionary        84
# Information Technology        70
# Financials                    68
# Industrials                   67
# Health Care                   61
# Consumer Staples              34
# Real Estate                   33
# Energy                        32
# Utilities                     28
# Materials                     25
# Telecommunication Services     3
# Name: Sector, dtype: int64

# %% [markdown]
# **Task: Replace Information Technology by "IT"**

# %%
#CODE HERE
lf1['Information Technology']:replace(['IT'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 #CODE HERE
# ----> 2 lf1['Information Technology']:replace(['IT'])
#
# NameError: name 'replace' is not defined

# %% [markdown]
# **Task: Add a \$ before the stock price**

# %%
# CODE HERE
